# %% [markdown]
# # Graphing pharmacies
#
# <img src = "https://plantcityorthodontist.com/wp-content/uploads/2023/07/busc-map-banner.jpg">

# %% [markdown]
# https://datos.gob.es/es/casos-exito/portalestadistico

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import json
from pandas.io.json import json_normalize
from shapely.geometry import Point, Polygon

# %% [markdown]
# # Wrangling Data

# %% [markdown]
# ### Main File, Json Pharmaceutical

# %%
file = '00 - Data/murcia_pharmaceutical.json'
df=pd.read_json(file,convert_dates=False,dtype='unicode')#,
df['Latitud'] =df['Latitud'].astype(float)
df['Longitud'] = df['Longitud'].astype(float)
df.head(3)
# Out:
#   Código                          Nombre            Dirección   C.P.  \
# 0   6733          CAYETANA CAMPILLO RUIZ  C/ Alfredo Nobel, 1  30509
# 1   1895  ABELLAN SEMITIEL, MARIA PIEDAD    Av. De Abarán, 32
# 2   1738          ABRIL SANCHEZ, ANTONIO       C/ Nogalte, 32
#
#           Municipio    Pedanía   Teléfono Fax                        Email  \
# 0  Molina de Segura  TORREALTA  968641743      farmaciatorrealta@gmail.com
# 1             Cieza      CIEZA  968730363
# 2             Lorca      LORCA  968466171
#
#   URL Real URL Corta       Latitud       Longitud  \
# 0                    -1.210817e+00      38.036954
# 1                     4.233166e+06  638942.000000
# 2                     4.170428e+06  614676.000000
#
#                                               Foto 1 Foto 2 Foto 3
# 0  http://www.murciaturistica.es/webs/murciaturis...    nan    nan
# 1                                                nan    nan    nan
# 2                                                nan    nan    nan

# %%
crs = {'init':'epsg:4326'}
geometry = [Point(xy) for xy in zip(df['Longitud'], df['Latitud'])]

geo_df = gpd.GeoDataFrame(df, #specify our data
                          crs=crs, #specify our coordinate reference system
                          geometry=geometry) #specify the geometry list we created
geo_df.head()
# Out:
#   Código                          Nombre            Dirección   C.P.  \
# 0   6733          CAYETANA CAMPILLO RUIZ  C/ Alfredo Nobel, 1  30509
# 1   1895  ABELLAN SEMITIEL, MARIA PIEDAD    Av. De Abarán, 32
# 2   1738          ABRIL SANCHEZ, ANTONIO       C/ Nogalte, 32
# 3   1836     AGUDO ESCUDERO, MARIA PILAR         C/ Mayor, 27  30430
# 4   1708      AGUILERA MUSSO, JOSE MARÍA   C/ Pablo Neruda, 5
#
#                 Municipio                  Pedanía     Teléfono Fax  \
# 0        Molina de Segura                TORREALTA    968641743
# 1                   Cieza                    CIEZA    968730363
# 2                   Lorca                    LORCA    968466171
# 3                 Cehegín                  CEHEGÍN  968 740 038
# 4  Las Torres de Cotillas  LAS TORRES DE COTILLAS     968626064
#
#                          Email URL Real URL Corta       Latitud  \
# 0  farmaciatorrealta@gmail.com                    -1.210817e+00
# 1                                                  4.233166e+06
# 2                                                  4.170428e+06
# 3                                                 -1.801298e+00
# 4                                                  4.210534e+06
#
#         Longitud                                             Foto 1 Foto 2  \
# 0      38.036954  http://www.murciaturistica.es/webs/murciaturis...    nan
# 1  638942.000000                                                nan    nan
# 2  614676.000000                                                nan    nan
# 3      38.096641  http://www.murciaturistica.es/webs/murciaturis...    nan
# 4  654320.000000                                                nan    nan
#
#   Foto 3                        geometry
# 0    nan           POINT (38.037 -1.211)
# 1    nan  POINT (638942.000 4233166.000)
# 2    nan  POINT (614676.000 4170428.000)
# 3    nan           POINT (38.097 -1.801)
# 4    nan  POINT (654320.000 4210534.000)

# %% [markdown]
# ### Additional Files for Geometry

# %%
# Spain Shapes file - Data from 2015
spain_shapes = gpd.read_file('00 - Data/population/6ace4d4a-5ca9-43d6-acc0-81de35da62002020329-1-xmcwky.ni6eh.shp')
spain_shapes.head(1)
# Out:
#    FID  OBJECTID_1  OBJECTID Codigo              Texto Cod_Prov Cod_CCAA  \
# 0    1           1         1  01001  AlegrÃ­a-Dulantzi       01       16
#
#   NUTS_0 NUTS_1 NUTS_2 NUTS_3  Poblacion  \
# 0     ES    ES2   ES21  ES211       2882
#
#                                             geometry
# 0  MULTIPOLYGON (((-2.53469 42.82247, -2.53412 42...

# %%
# Murcia Shapes
murcia_shapes = spain_shapes.copy().loc[spain_shapes.Cod_Prov == "30"]

# %% [markdown]
# ----

# %%
# Population data updated

population = pd.read_csv('00 - Data/population_2021.csv', sep=';',decimal= ',' ,thousands=".")
population['Codigo Municipio'] = population['Codigo Municipio'].astype(str)

# we will transformate into integer, the numerical features
numerical_columns = ['Total','Hombres','Mujeres','TOTAL <16','Hombres <16','Mujeres <16','TOTAL 16-64','Hombres 16-64','Mujeres 16-64','TOTAL +65','Hombres +65','Mujeres +65']

population.head(2)
# Out:
#   Municipio  Total  Hombres  Mujeres  TOTAL <16  Hombres <16  Mujeres <16  \
# 0  Abanilla   6047     3064     2983        792          416          376
# 1    Abarán  13080     6525     6555       2082         1025         1057
#
#    TOTAL 16-64  Hombres 16-64  Mujeres 16-64  TOTAL +65  Hombres +65  \
# 0         3680           1922           1758       1575          726
# 1         8690           4501           4189       2308          999
#
#    Mujeres +65 Codigo Municipio
# 0          849            30001
# 1         1309            30002

# %% [markdown]
# We will merge this file with our original files of shapes, in order to get more updated values for population, and also splitted by sex and age

# %%
merged_population = pd.merge(murcia_shapes, population, how='left', left_on = 'Codigo', right_on='Codigo Municipio')

# %%
merged_population.head(1).transpose()
# Out:
#                                                                   0
# FID                                                            4561
# OBJECTID_1                                                     4561
# OBJECTID                                                       4561
# Codigo                                                        30001
# Texto                                                      Abanilla
# Cod_Prov                                                         30
# Cod_CCAA                                                         14
# NUTS_0                                                           ES
# NUTS_1                                                          ES6
# NUTS_2                                                         ES62
# NUTS_3                                                        ES620
# Poblacion                                                      6347
# geometry          POLYGON ((-1.06881260641904 38.3457359352243, ...
# Municipio                                                  Abanilla
# Total                                                          6047
# Hombres                                                        3064
# Mujeres                                                        2983
# TOTAL <16                                                       792
# Hombres <16                                                     416
# Mujeres <16                                                     376
# TOTAL 16-64                                                    3680
# Hombres 16-64                                                  1922
# Mujeres 16-64                                                  1758
# TOTAL +65                                                      1575
# Hombres +65                                                     726
# Mujeres +65                                                     849
# Codigo Municipio                                              30001

# %%
# we will delete some unnecesary columns
drop_columns = ['Cod_Prov','Cod_CCAA','NUTS_0','NUTS_1','NUTS_2','NUTS_3','Poblacion']
merged_population = merged_population.drop(drop_columns, axis=1)

# %% [markdown]
# # Visualizations

# %%
fig, ax = plt.subplots(figsize=(20,20))
merged_population.plot(ax=ax, alpha=0.4, column='Texto', cmap='gist_rainbow')
plt.title('Murcia Territory', size=30);

# Add annotations for 'total' values in Map 1
for idx, row in merged_population.iterrows():
    annotation_text = row['Texto']
    ax.annotate(text=annotation_text,
                    xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                    xytext=(3, 3),  # offset for the text
                    textcoords="offset points",
                    ha='center', va='center',
                    fontsize=8, color='black')
# Out:
# C:\Users\juans\anaconda3\envs\dhdsblend\lib\site-packages\IPython\core\events.py:88: UserWarning: Glyph 129 (\x81) missing from current font.
#   func(*args, **kwargs)
# C:\Users\juans\anaconda3\envs\dhdsblend\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig, ax = plt.subplots(figsize=(20,20))
merged_population.plot(ax=ax, alpha=0.4, column='Total', cmap='coolwarm',legend=True,  vmax=50000,
                      legend_kwds={"label": "Murcia Population 2021", "orientation": "horizontal"})
plt.title('Murcia Population', size=30);

# Add annotations for 'total' values in Map 1
for idx, row in merged_population.iterrows():
    annotation_text = row['Texto'] + '\n'+str(row['Total'])
    ax.annotate(text=annotation_text,
                    xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                    xytext=(3, 3),  # offset for the text
                    textcoords="offset points",
                    ha='center', va='center',
                    fontsize=8, color='black')
# Out:
# C:\Users\juans\anaconda3\envs\dhdsblend\lib\site-packages\IPython\core\events.py:88: UserWarning: Glyph 129 (\x81) missing from current font.
#   func(*args, **kwargs)
# C:\Users\juans\anaconda3\envs\dhdsblend\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# As we can see, the refions with more population are:
# * Murcia: 459778
# * Cartagena: 215826
# * Lorca: 95726
# * Molina de Segura: 73593

# %%
fig, ax = plt.subplots(figsize=(20,20))
merged_population.plot(ax=ax, alpha=0.4, column='TOTAL +65', cmap='coolwarm',legend=True,  vmax=30000,
                      legend_kwds={"label": "Murcia Old Population 2021", "orientation": "horizontal"})
plt.title('Murcia +65 Population', size=30);

# Add annotations for 'total' values in Map 1
for idx, row in merged_population.iterrows():
    annotation_text = row['Texto'] + '\n'+str(row['Total'])
    ax.annotate(text=annotation_text,
                    xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                    xytext=(3, 3),  # offset for the text
                    textcoords="offset points",
                    ha='center', va='center',
                    fontsize=8, color='black')
# Out:
# C:\Users\juans\anaconda3\envs\dhdsblend\lib\site-packages\IPython\core\events.py:88: UserWarning: Glyph 129 (\x81) missing from current font.
#   func(*args, **kwargs)
# C:\Users\juans\anaconda3\envs\dhdsblend\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Makes sense that the same pattern applies if we filter by +65 population.
#
# But, under the assumption that older population is more likely to need medicine, we will analyze the ratio of +65 over total, per each location

# %%
merged_population['65_ratio'] = merged_population['TOTAL +65'] / merged_population['Total']

# %%
fig, ax = plt.subplots(figsize=(20,20))
merged_population.plot(ax=ax, alpha=0.4, column='65_ratio', cmap='coolwarm',legend=True, vmin = 0,
                      legend_kwds={"label": "Murcia Old Population 2021 over Total Pop", "orientation": "horizontal"})
plt.title('Murcia +65 Population', size=30);

# Add annotations for 'total' values in Map 1
for idx, row in merged_population.iterrows():
    annotation_text = row['Texto'] + '\n'+str(round(row['65_ratio'],2))
    ax.annotate(text=annotation_text,
                    xy=(row.geometry.centroid.x, row.geometry.centroid.y),
                    xytext=(3, 3),  # offset for the text
                    textcoords="offset points",
                    ha='center', va='center',
                    fontsize=8, color='black')
# Out:
# C:\Users\juans\anaconda3\envs\dhdsblend\lib\site-packages\IPython\core\events.py:88: UserWarning: Glyph 129 (\x81) missing from current font.
#   func(*args, **kwargs)
# C:\Users\juans\anaconda3\envs\dhdsblend\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# In this case, while plotting the % of people older than 65 Years, we found that the top locations are:
# * Ricote
# * Villanueva
# * Albanilla
# * Aledo

# %% [markdown]
# ---

# %%
fig, ax = plt.subplots(figsize=(20,20))
merged_population.plot(ax=ax, color='grey')
geo_df.loc[geo_df['C.P.']!=""].plot(ax=ax)
# Out:
# <AxesSubplot:>

# %%
geo_df.groupby('Municipio')['Código'].count()
# Out:
# Municipio
# Abanilla                      4
# Abarán                        4
# Albudeite                     1
# Alcantarilla                 11
# Aledo                         1
# Alguazas                      2
# Alhama de Murcia              6
# Archena                       3
# Beniel                        3
# Blanca                        3
# Bullas                        4
# Calasparra                    4
# Campos del Río                1
# Caravaca de la Cruz           6
# Cartagena                    60
# Cehegín                       5
# Ceutí                         3
# Cieza                        10
# Fortuna                       2
# Fuente Álamo                  2
# Jumilla                       7
# La Manga                      6
# La Unión                      6
# Las Torres de Cotillas        5
# Librilla                      2
# Lorca                         9
# Lorquí                        2
# Los Alcázares                 6
# Mazarrón                     11
# Molina de Segura             15
# Moratalla                     3
# Mula                          5
# Murcia                       33
# Ojós                          1
# Pliego                        1
# Puerto Lumbreras              5
# Ricote                        1
# San Javier                   11
# San Pedro del Pinatar         9
# Santomera                     3
# Torre Pacheco                 7
# Totana                        7
# Ulea                          1
# Villanueva del Rio Segura     1
# Yecla                        12
# Águilas                      12
# Name: Código, dtype: int64
